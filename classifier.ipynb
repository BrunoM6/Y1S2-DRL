# %% [markdown]
# # Data Loading and Analysis

# %%
import os
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from cnn import ImageBatchDataset

FOLDERS = ["inpainting", "insight", "text2img", "wiki"]
DATA_DIR = "data"
BATCH_SIZE = 32

transform = transforms.Compose([
    transforms.ToTensor()
])

dataset = ImageBatchDataset(FOLDERS, DATA_DIR, transform=transform)
loader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=-1)

print(f"Found images: {len(dataset)}")

for i, batch_tensors in enumerate(loader):
# Out:
# Loaded: 14609100_1984-03-14_2008.jpg with shape (512, 512, 3)
# Loaded: 1878100_1958-09-13_1993.jpg with shape (512, 512, 3)
# Loaded: 19248600_1958-05-25_2015.jpg with shape (512, 512, 3)
# Loaded: 42842300_1994-10-18_2014.jpg with shape (512, 512, 3)
# Loaded: 11736200_1930-09-26_1953.jpg with shape (512, 512, 3)
# Loaded: 6774400_1969-07-18_2009.jpg with shape (512, 512, 3)
# Loaded: 13016000_1987-01-20_2009.jpg with shape (512, 512, 3)
# Loaded: 21718500_1986-06-01_2010.jpg with shape (512, 512, 3)
# Loaded: 14429000_1885-11-19_1941.jpg with shape (512, 512, 3)
# Loaded: 22768200_1986-07-11_2008.jpg with shape (512, 512, 3)
# Loaded: 1716100_1958-02-13_2013.jpg with shape (512, 512, 3)
# Loaded: 35555300_1989-11-09_2012.jpg with shape (512, 512, 3)
# Loaded: 22520700_1975-02-02_2012.jpg with shape (512, 512, 3)
# Loaded: 1915100_1957-07-20_1990.jpg with shape (512, 512, 3)
# Loaded: 44626200_1982-05-31_2012.jpg with shape (512, 512, 3)
# ...
